# %%
import pandas as pd

df = pd.read_csv("../data/processed/clean_weather_data.csv")

df.head()
# Out:
#         City Country  Latitude  Longitude  Temperature  Humidity  Pressure  \
# 0     Mumbai   India    19.076     72.877        26.10        68      1011
# 1      Delhi   India    28.613     77.209        24.69        16      1009
# 2  Bangalore   India    12.971     77.594        24.03        46      1011
# 3    Chennai   India    13.082     80.270        25.83        70      1011
# 4    Kolkata   India    22.572     88.363        23.09        77      1009
#
#   Weather_Description             Datetime
# 0           clear sky  2026-03-16 11:08:46
# 1     overcast clouds  2026-03-16 11:02:49
# 2     overcast clouds  2026-03-16 11:11:08
# 3          few clouds  2026-03-16 11:06:53
# 4       moderate rain  2026-03-16 11:03:00

# %%
len(df)
# Out:
# 100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 100 non-null    object
#  1   Country              100 non-null    object
#  2   Latitude             100 non-null    float64
#  3   Longitude            100 non-null    float64
#  4   Temperature          100 non-null    float64
#  5   Humidity             100 non-null    int64
#  6   Pressure             100 non-null    int64
#  7   Weather_Description  100 non-null    object
#  8   Datetime             100 non-null    object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 7.2+ KB

# %%
df["Datetime"].head(20)
# Out:
# 0     2026-03-16 11:08:46
# 1     2026-03-16 11:02:49
# 2     2026-03-16 11:11:08
# 3     2026-03-16 11:06:53
# 4     2026-03-16 11:03:00
# 5     2026-03-16 11:11:11
# 6     2026-03-16 11:01:12
# 7     2026-03-16 11:10:36
# 8     2026-03-16 11:11:14
# 9     2026-03-16 11:11:15
# 10    2026-03-16 11:11:15
# 11    2026-03-16 11:11:16
# 12    2026-03-16 11:11:17
# 13    2026-03-16 11:11:18
# 14    2026-03-16 11:11:19
# 15    2026-03-16 11:11:20
# 16    2026-03-16 11:11:21
# 17    2026-03-16 11:11:22
# 18    2026-03-16 11:11:23
# 19    2026-03-16 11:11:24
# Name: Datetime, dtype: object

# %%
df["Datetime"]=df["Datetime"].astype(str).str.replace(r"\..*","",regex=True)

# %%
df["Datetime"].head()
# Out:
# 0    22:30
# 1    22:31
# 2    22:35
# 3    22:39
# 4    22:41
# Name: Datetime, dtype: object

# %%
df["Datetime"] = pd.to_datetime(df["Datetime"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1720\2025342699.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Datetime"] = pd.to_datetime(df["Datetime"])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:679, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df["Datetime"] = pd.to_datetime(df["Datetime"])
#
# ...

# %%
df = df.dropna(subset=["Datetime"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 180 non-null    object
#  1   Country              180 non-null    object
#  2   Latitude             180 non-null    float64
#  3   Longitude            180 non-null    float64
#  4   Temperature          180 non-null    float64
#  5   Humidity             180 non-null    int64
#  6   Pressure             180 non-null    float64
#  7   Weather_Description  180 non-null    object
#  8   Datetime             180 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(3)
# memory usage: 14.1+ KB

# %%
df["Datetime"] = pd.to_datetime(df["Datetime"])

# %%
df["Datetime"].head(20)
# Out:
# 0    2026-03-16 22:30:06
# 1    2026-03-16 22:31:54
# 2    2026-03-16 22:35:24
# 3    2026-03-16 22:39:18
# 4    2026-03-16 22:41:06
# 5    2026-03-16 22:43:06
# 6    2026-03-16 22:45:42
# 7    2026-03-16 22:48:30
# 8    2026-03-16 22:50:30
# 9    2026-03-16 22:52:06
# 10   2026-03-16 22:53:30
# 11   2026-03-16 22:57:18
# 12   2026-03-16 22:58:42
# 13   2026-03-16 23:00:18
# 14   2026-03-16 23:01:48
# 15   2026-03-16 23:03:42
# 16   2026-03-16 23:05:42
# 17   2026-03-16 23:07:18
# 18   2026-03-16 23:10:00
# 19   2026-03-16 23:12:36
# Name: Datetime, dtype: datetime64[ns]

# %%
df["Datetime"] = df["Datetime"].astype(str).str.replace(".1","", regex=False)

# %%
df["Datetime"] = pd.to_datetime(df["Datetime"], errors="coerce")

# %%
df["Datetime"].isna().sum()
# Out:
# 7
